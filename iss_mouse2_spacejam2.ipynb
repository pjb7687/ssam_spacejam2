# %%
from collections import defaultdict
import numpy as np

minmax_x = [9999999999999, -9999999999999]
minmax_y = [9999999999999, -9999999999999]

pos_dic = defaultdict(lambda: [])
with open("data/iss/mouse2/ISS_2_spot_table.csv") as f:
    print(f.readline())
    for line in f:
        entries = line.rstrip().split(',')
        x = float(entries[2])
        y = float(entries[3])
        g = entries[1]
        if g == "":
            continue
        pos_dic[g].append([x, y])
        if x < minmax_x[0]:
            minmax_x[0] = x
        if x > minmax_x[1]:
            minmax_x[1] = x
        if y < minmax_y[0]:
            minmax_y[0] = y
        if y > minmax_y[1]:
            minmax_y[1] = y
for g in pos_dic:
    pos_dic[g] = np.array(pos_dic[g])
# Out:
# ,gene,x_um,y_um

# %%
all_genes = sorted(pos_dic.keys())
mrna_loci = [pos_dic[gene] for gene in all_genes]

# %%
minmax_x, minmax_y
# Out:
# ([9.1, 4546.425], [12.675, 3048.5])

# %%
width, height = 4547, 3049

# %%
import ssam

# %%
ds = ssam.SSAMDataset(all_genes, mrna_loci, width, height)
analysis = ssam.SSAMAnalysis(ds, ncores=10, save_dir="data/iss_mouse2", verbose=True)

# %%
analysis.run_fast_kde(bandwidth=2.5, use_mmap=False)
# Out:
# Processing gene 3110035E14Rik...
# Processing gene Adarb2...
# Processing gene Arx...
# Processing gene Alcam...
# Processing gene Arpp19...
# Processing gene Ankrd55...
# Processing gene Ank1...
# Processing gene Adcy2...
# Processing gene Atp1a3...
# Processing gene Bdnf...
# Processing gene Brinp3...
# Processing gene Btbd11...
# Processing gene Cacna2d3...
# Processing gene Calb1...
# Processing gene Caln1...
# Processing gene Camk2n1...
# Processing gene Car3...
# Processing gene Car4...
# Processing gene Cck...
# Processing gene Cd34...
# Processing gene Cdh13...
# Processing gene Cdh9...
# Processing gene Chodl...
# Processing gene Chrna2...
# Processing gene Cnr1...
# Processing gene Cplx3...
# Processing gene Cpne7...
# Processing gene Crh...
# Processing gene Cryab...
# Processing gene Crym...
# Processing gene Ctxn1...
# Processing gene Cxcl14...
# Processing gene Dcn...
# Processing gene Deptor...
# Processing gene Dgkb...
# Processing gene Dlx1...
# Processing gene Dlx6os1...
# Processing gene Etv1...
# Processing gene Fa2h...
# Processing gene Fam19a1...
# Processing gene Fam84b...
# Processing gene Fezf2...
# Processing gene Fgf13...
# Processing gene Fgfr3...
# Processing gene Fxyd6...
# Processing gene Gabra1...
# Processing gene Gad1...
# Processing gene Gad2...
# Processing gene Gm11549...
# Processing gene Grik1...
# Processing gene Hpca...
# Processing gene Hs3st2...
# Processing gene Id2...
# Processing gene Igfbp4...
# Processing gene Igfbp6...
# Processing gene Igsf21...
# Processing gene Itpka...
# Processing gene Kcnip1...
# Processing gene Kcnip4...
# Processing gene Kcnmb2...
# Processing gene Lamp5...
# Processing gene Lhx6...
# Processing gene Lrrtm4...
# Processing gene Luzp2...
# Processing gene Ly6c2...
# Processing gene Ly86...
# Processing gene Malat1...
# Processing gene Map3k7cl...
# Processing gene Meis2...
# Processing gene Mgat4c...
# Processing gene Ndnf...
# Processing gene Ndrg4...
# Processing gene Nek7...
# Processing gene Neurod1...
# Processing gene Neurod6...
# Processing gene Nfib...
# Processing gene Nov...
# Processing gene Npas1...
# Processing gene Npy...
# Processing gene Nrgn...
# Processing gene Nrn1...
# Processing gene Nrxn1...
# Processing gene Nxph1...
# Processing gene Nxph4...
# Processing gene Pantr1...
# Processing gene Pcp4...
# Processing gene Pcp4l1...
# Processing gene Pde1a...
# Processing gene Pdgfra...
# Processing gene Penk...
# Processing gene Ppapdc1a...
# Processing gene Pthlh...
# Processing gene Ptn...
# Processing gene Ptprd...
# Processing gene Ptprt...
# Processing gene Pvalb...
# Processing gene R3hdm1...
# Processing gene Rab3b...
# Processing gene Rab3c...
# Processing gene Rasl10a...
# Processing gene Reln...
# Processing gene Rgs10...
# Processing gene Rgs4...
# Processing gene Rorb...
# Processing gene Rprml...
# Processing gene Rspo1...
# Processing gene Sema3e...
# Processing gene Serpine2...
# Processing gene Serpini1...
# Processing gene Sez6...
# Processing gene Slc17a7...
# Processing gene Slc1a2...
# Processing gene Slc32a1...
# Processing gene Slc6a1...
# Processing gene Snca...
# Processing gene Sncg...
# Processing gene Snhg11...
# Processing gene Snrpn...
# Processing gene Sparcl1...
# Processing gene Sst...
# Processing gene Stxbp6...
# Processing gene Sv2b...
# Processing gene Synpr...
# Processing gene Syt1...
# Processing gene Syt6...
# Processing gene Tac2...
# Processing gene Tesc...
# Processing gene Th...
# Processing gene Thsd7a...
# Processing gene Tmsb10...
# Processing gene Tmsb4x...
# Processing gene Vip...
# Processing gene Zmat4...

# %%
import pickle
with open("scrna_sigs.pkl", "rb") as f:
    scrna_clusters, scrna_genes, scrna_full_centroids, scrna_colors = pickle.load(f)

# %%
gene_conv_dic ={
    "Ngfrap1": "Bex3",
    "Gucy1a3": "Gucy1a1",
    "Ppap2b": "Plpp3",
    "Selm": "Selenom",
    #"3110035E14Rik": "Vxn",
    "Plpp4": "Ppapdc1a",
    #"Fam84b": "Lratd2"
}

# %%
for f, t in gene_conv_dic.items():
    scrna_genes = np.where(scrna_genes == f, t, scrna_genes)

# %%
selected_genes_idx = [list(scrna_genes).index(g) for g in ds.genes]
scrna_uniq_clusters = np.unique(scrna_clusters)
scrna_centroids = scrna_full_centroids[:, selected_genes_idx]

# %%
import matplotlib.pyplot as plt

# %%
norm_thres = 0.05
gidx = 0
plt.figure(figsize=[5, 2])
#plt.hist(ds.vf[..., gidx][ds.vf[..., gidx] > 0], bins=100, log=True)
n, _, _ = plt.hist(ds.vf_norm[np.logical_and(ds.vf_norm > 0, ds.vf_norm < 0.3)], bins=100, log=True, histtype='step')
ax = plt.gca()
ax.axvline(norm_thres, c='red', ls='--')
ax.set_xlabel("L1-norm")
ax.set_ylabel("Count")

plt.xlim([0, 0.3])
plt.ylim([np.min(n), np.max(n) + 100000])
pass

# %%
analysis.map_celltypes(scrna_centroids)

# %%
analysis.filter_celltypemaps(min_norm=0.02, min_r=0.3)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[30,30])
_ = ds.plot_celltypes_map(rotate=0, colors=scrna_colors)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[20,20])
_ = ds.plot_celltypes_map(rotate=0, colors=scrna_colors)
plt.xlim([1000, 2000])
plt.ylim([3000, 2000])
# Out:
# (3000, 2000)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[20,20])
_ = ds.plot_celltypes_map(rotate=0, colors=scrna_colors, centroid_indices=[29])
plt.xlim([1000, 2000])
plt.ylim([3000, 2000])
# Out:
# (3000, 2000)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[20,20])
plt.imshow(ds.vf[..., 0, ds.genes.index("Chodl")])
plt.xlim([1000, 2000])
plt.ylim([3000, 2000])
# Out:
# (3000, 2000)

# %%
analysis.bin_celltypemaps(step=10, radius=100)
analysis.find_domains(n_clusters=20, merge_remote=False, merge_thres=0.9, norm_thres=1500)
plt.figure(figsize=[15, 15])
ds.plot_domains(rotate=1)
