# %%
from collections import defaultdict
import numpy as np

minmax_x = [9999999999999, -9999999999999]
minmax_y = [9999999999999, -9999999999999]

pos_dic = defaultdict(lambda: [])
with open("data/dartfish/human1/DARTFISH_DecodedSpots_Hs_FCtx_20180122.csv") as f:
    f.readline()
    for line in f:
        entries = line.rstrip().split(',')
        x = float(entries[4])
        y = float(entries[5])
        g = entries[0]
        pos_dic[g].append([x, y])
        if x < minmax_x[0]:
            minmax_x[0] = x
        if x > minmax_x[1]:
            minmax_x[1] = x
        if y < minmax_y[0]:
            minmax_y[0] = y
        if y > minmax_y[1]:
            minmax_y[1] = y
for g in pos_dic:
    pos_dic[g] = np.array(pos_dic[g])

# %%
all_genes = sorted(pos_dic.keys())
mrna_loci = [pos_dic[gene] for gene in all_genes]

# %%
minmax_x, minmax_y
# Out:
# ([1.520000001, 5083.5456], [0.486, 171.1224])

# %%
width, height = 5100, 190

# %%
import ssam

# %%
ds = ssam.SSAMDataset(all_genes, mrna_loci, width, height)
analysis = ssam.SSAMAnalysis(ds, ncores=10, save_dir="data/dartfish_human1", verbose=True)

# %%
analysis.run_fast_kde(bandwidth=2.5, use_mmap=False)
# Out:
# Processing gene ACOT11...
# Processing gene ABCC9...
# Processing gene ANXA1...
# Processing gene ADTRP...
# Processing gene ADCY8...
# Processing gene ADRA2A...
# Processing gene ANKRD13A...
# Processing gene AHRR...
# Processing gene ANKRD18A...
# Processing gene APOD...
# Processing gene ARSJ...
# Processing gene ASPA...
# Processing gene ATP10A...
# Processing gene ATP2C2...
# Processing gene ATP8B1...
# Processing gene B3GAT2...
# Processing gene BCL11A...
# Processing gene BCL11B...
# Processing gene BHLHE22...
# Processing gene C10orf11...
# Processing gene C1QA...
# Processing gene C1QB...
# Processing gene C1QC...
# Processing gene CACNA2D2...
# Processing gene CALB1...
# Processing gene CALB2...
# Processing gene CAPN3...
# Processing gene CCDC141...
# Processing gene CCDC88C...
# Processing gene CCK...
# Processing gene CCL3...
# Processing gene CCR1...
# Processing gene CCR5...
# Processing gene CCRL2...
# Processing gene CD33...
# Processing gene CD37...
# Processing gene CD83...
# Processing gene CDC14A...
# Processing gene CDH9...
# Processing gene CELF4...
# Processing gene CELF6...
# Processing gene CHST8...
# Processing gene CLDN11...
# Processing gene CLMN...
# Processing gene CLSTN2...
# Processing gene CLTCL1...
# Processing gene CNP...
# Processing gene CNR1...
# Processing gene CNTNAP3...
# Processing gene COL20A1...
# Processing gene COL24A1...
# Processing gene COL25A1...
# Processing gene COL5A2...
# Processing gene COL6A1...
# Processing gene CRABP1...
# Processing gene CREB5...
# Processing gene CRHBP...
# Processing gene CRIM1...
# Processing gene CRTAC1...
# Processing gene CSF1R...
# Processing gene CSF3R...
# Processing gene CTNNA3...
# Processing gene CTSS...
# Processing gene CUX2...
# Processing gene CX3CR1...
# Processing gene CXXC4...
# Processing gene DCHS2...
# Processing gene DKK3...
# Processing gene DLC1...
# Processing gene DLX1...
# Processing gene DLX2...
# Processing gene DLX5...
# Processing gene DLX6...
# Processing gene DPYSL5...
# Processing gene DSP...
# Processing gene DYNC1I1...
# Processing gene EBF3...
# Processing gene ECSCR...
# Processing gene EMID1...
# Processing gene ENPP6...
# Processing gene ERMN...
# Processing gene EVI2A...
# Processing gene EXPH5...
# Processing gene FA2H...
# Processing gene FAM151B...
# Processing gene FEZF2...
# Processing gene FIBIN...
# Processing gene FOXP2...
# Processing gene FRAS1...
# Processing gene FREM1...
# Processing gene FREM2...
# Processing gene GABRG1...
# Processing gene GAD1...
# Processing gene GAD2...
# Processing gene GALNT14...
# Processing gene GAS2L3...
# Processing gene GDF15...
# Processing gene GDF5...
# Processing gene GFRA1...
# Processing gene GHR...
# Processing gene GJB1...
# Processing gene GLRA2...
# Processing gene GNA15...
# Processing gene GNAL...
# Processing gene GNG11...
# Processing gene GNG4...
# Processing gene GPR149...
# Processing gene GNGT2...
# Processing gene GPR153...
# Processing gene GPR83...
# Processing gene GRAP...
# Processing gene GREB1L...
# Processing gene GREM2...
# Processing gene GRIK3...
# Processing gene GRIN3A...
# Processing gene GRM2...
# Processing gene GRM4...
# Processing gene GSN...
# Processing gene HCN4...
# Processing gene HCRTR2...
# Processing gene HGF...
# Processing gene HMHA1...
# Processing gene HPCAL1...
# Processing gene HPSE2...
# Processing gene HS3ST4...
# Processing gene HS3ST5...
# Processing gene IFITM10...
# Processing gene IGFBP5...
# Processing gene IGFBPL1...
# Processing gene IL10RA...
# Processing gene IL1A...
# Processing gene IL1RAPL2...
# Processing gene IRF5...
# Processing gene INPP5D...
# Processing gene ISLR2...
# Processing gene ITGA8...
# Processing gene ITGAM...
# Processing gene JAG1...
# Processing gene ITGB8...
# Processing gene KCNH7...
# Processing gene KCNJ5...
# Processing gene KCNK9...
# Processing gene KIAA1217...
# Processing gene KIT...
# Processing gene KLHL1...
# Processing gene KMO...
# Processing gene L1CAM...
# Processing gene LAMA2...
# Processing gene LAMP5...
# Processing gene LAPTM5...
# Processing gene LHFPL5...
# Processing gene LHX1...
# Processing gene LHX6...
# Processing gene LIMS1...
# Processing gene LRCH4...
# Processing gene LRRC25...
# Processing gene LRRC38...
# Processing gene LRRC3B...
# Processing gene LTBP1...
# Processing gene LUZP2...
# Processing gene MAB21L1...
# Processing gene MAF...
# Processing gene MAG...
# Processing gene MAGEL2...
# Processing gene MAL...
# Processing gene MARCH4...
# Processing gene MAMDC2...
# Processing gene MBP...
# Processing gene MCC...
# Processing gene MCTP2...
# Processing gene MDGA1...
# Processing gene MEG3...
# Processing gene MGAT5...
# Processing gene MN1...
# Processing gene MOBP...
# Processing gene MOG...
# Processing gene MRAP2...
# Processing gene MYB...
# Processing gene MYH11...
# Processing gene MYO10...
# Processing gene NCF1...
# Processing gene NECAB2...
# Processing gene NELL1...
# Processing gene NEUROD6...
# Processing gene NHLH2...
# Processing gene NKX6-2...
# Processing gene NLRP3...
# Processing gene NOS1...
# Processing gene NOSTRIN...
# Processing gene NPAS4...
# Processing gene NR4A2...
# Processing gene NPY...
# Processing gene NTNG1...
# Processing gene NTNG2...
# Processing gene NTRK1...
# Processing gene NXPH4...
# Processing gene OLFM1...
# Processing gene NotAssigned...
# Processing gene OLFML2B...
# Processing gene OLFML3...
# Processing gene OPALIN...
# Processing gene OSM...
# Processing gene OVOL2...
# Processing gene P2RX5...
# Processing gene P2RY13...
# Processing gene PAH...
# Processing gene PAPSS2...
# Processing gene PCDH20...
# Processing gene PCDH8...
# Processing gene PCED1B...
# Processing gene PCP4...
# Processing gene PCSK1...
# Processing gene PCSK5...
# Processing gene PDE1A...
# Processing gene PDE9A...
# Processing gene PDGFD...
# Processing gene PDGFRA...
# Processing gene PDLIM5...
# Processing gene PDYN...
# Processing gene PECAM1...
# Processing gene PLCXD2...
# Processing gene PLCXD3...
# Processing gene PLD1...
# Processing gene PLD4...
# Processing gene PLD5...
# Processing gene PLP1...
# Processing gene POSTN...
# Processing gene PPP1R14A...
# Processing gene PREX1...
# Processing gene PRLR...
# Processing gene PRRX1...
# Processing gene PTPRU...
# Processing gene PVALB...
# Processing gene RAB20...
# Processing gene RASAL3...
# Processing gene RASGEF1C...
# Processing gene RASSF3...
# Processing gene RBM20...
# Processing gene RCSD1...
# Processing gene RGS1...
# Processing gene RELN...
# Processing gene RGS12...
# Processing gene RIN2...
# Processing gene RNF152...
# Processing gene RNF182...
# Processing gene ROBO2...
# Processing gene RORB...
# Processing gene RPH3AL...
# Processing gene RRBP1...
# Processing gene RYR3...
# Processing gene SCTR...
# Processing gene SCUBE3...
# Processing gene SDK2...
# Processing gene SELPLG...
# Processing gene SEMA3E...
# Processing gene SEMA5A...
# Processing gene SERPINE2...
# Processing gene SFMBT2...
# Processing gene SLC10A4...
# Processing gene SLC11A1...
# Processing gene SLC12A7...
# Processing gene SLC15A3...
# Processing gene SLC17A6...
# Processing gene SLC17A7...
# Processing gene SLC25A45...
# Processing gene SLC32A1...
# Processing gene SLC6A1...
# Processing gene SLC6A11...
# Processing gene SLC7A11...
# Processing gene SLCO2B1...
# Processing gene SMYD1...
# Processing gene SNHG11...
# Processing gene SNTB1...
# Processing gene SP8...
# Processing gene SRRM4...
# Processing gene SPOCK3...
# Processing gene SST...
# Processing gene ST8SIA2...
# Processing gene STK32B...
# Processing gene SULF1...
# Processing gene SWAP70...
# Processing gene SYNDIG1L...
# Processing gene SYNPR...
# Processing gene SYT10...
# Processing gene SYT2...
# Processing gene SYT6...
# Processing gene TAC3...
# Processing gene TACR1...
# Processing gene TBR1...
# Processing gene TESC...
# Processing gene TEK...
# Processing gene TGFB1...
# Processing gene TH...
# Processing gene TLE4...
# Processing gene TLL1...
# Processing gene TLR2...
# Processing gene TLR7...
# Processing gene TMEM119...
# Processing gene TMEM125...
# Processing gene TMEM130...
# Processing gene TMEM255A...
# Processing gene TMEM63A...
# Processing gene TNF...
# Processing gene TNFAIP8L3...
# Processing gene TNFRSF1B...
# Processing gene TNNT2...
# Processing gene TOX...
# Processing gene TREM2...
# Processing gene TRHDE...
# Processing gene TRPC3...
# Processing gene TRIM66...
# Processing gene TRPC5...
# Processing gene TRPM4...
# Processing gene TSHZ2...
# Processing gene TSPAN18...
# Processing gene TXK...
# Processing gene TYROBP...
# Processing gene UNC93B1...
# Processing gene VAV2...
# Processing gene VAV3...
# Processing gene VIP...
# Processing gene VIPR2...
# Processing gene VSTM2L...
# Processing gene ZFHX3...
# Processing gene ZNF385D...
# Processing gene ZNF703...
# Processing gene ZNF804B...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[5, 50])
plt.imshow(ds.vf_norm[..., 0])
